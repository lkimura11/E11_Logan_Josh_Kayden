# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd

data = pd.read_csv('pm2.5data.csv')

print(data)

plt.hist(data, bins=3)
plt.xlabel('PM 2.5 Value')
plt.ylabel('Frequency')
# Out:
#     3
# 0   3
# 1   2
# 2   2
# 3   2
# 4   2
# .. ..
# 67  3
# 68  3
# 69  3
# 70  2
# 71  2
#
# [72 rows x 1 columns]
# Text(0, 0.5, 'Frequency')
